# %% [markdown]
# # Sentiment analysis (Exercise 4)

# %%
__author__ = "Paloma Jeretic"
__version__ = "DSGA 1012, NYU, Spring 2018 term"

# %% [markdown]
# ## Setup

# %% [markdown]
# First, let's load the Stanford Sentiment Treebank. If you don't already have it, download it from here: [the train/dev/test Stanford Sentiment Treebank distribution](http://nlp.stanford.edu/sentiment/trainDevTestTrees_PTB.zip), unzip it, and put the resulting folder in the same directory as this notebook. (If you want to put it somewhere else, change `sst_home` below.)

# %%
import re
import random
import os
import numpy as np
import collections

# %%
sst_home = 'trees'

def load_sst_data(path):
    # Let's do 2-way positive/negative classification instead of 5-way
    EASY_LABEL_MAP = {0:0, 1:0, 2:None, 3:1, 4:1}
    
    data = []
    with open(path) as f:
        for i, line in enumerate(f): 
            example = {}
            example['label'] = EASY_LABEL_MAP[int(line[1])]
            if example['label'] is None:
                continue
            
            # Strip out the parse information and the phrase labels---we don't need those here
            text = re.sub(r'\s*(\(\d)|(\))\s*', '', line)
            example['text'] = text[1:]
            data.append(example)

    return data
     
training_set = load_sst_data(sst_home + '/train.txt')
dev_set = load_sst_data(sst_home + '/dev.txt')
#test_set = load_sst_data(sst_home + '/test.txt')

# %% [markdown]
# We will be using IMDb movie reviews as a test set later on. Download the data <a href="http://ai.stanford.edu/~amaas/data/sentiment/">here</a>, unzip it, and put the resulting folder in the same directory as this notebook.
#
# The following function reformats it in the same form as our SST data.

# %%
imdb_home = 'aclImdb/test/'

def load_imdb_data(path):
    
    pos_data, neg_data = [], []
    all_files = []
    _limit = 250
    
    for dirpath, dirnames, files in os.walk(path):
        for name in files:
            all_files.append(os.path.join(dirpath, name))
            
            
    for file_path in all_files:
        if '/neg' in file_path and len(neg_data) <= _limit:
            example = {}
            with open(file_path, 'r') as myfile:
                example['text'] = myfile.read().replace('\n', '')
            example['label'] = 0
            neg_data.append(example)
            
        if '/pos' in file_path and len(pos_data) <= _limit:
            example = {}
            with open(file_path, 'r') as myfile:
                example['text'] = myfile.read().replace('\n', '')
            example['label'] = 1
            pos_data.append(example)
    data = neg_data + pos_data

    return data

            
imdb_test = load_imdb_data(imdb_home)

# %%
imdb_test[0]
# Out:
# {'label': 0,
#  'text': "Alan Rickman & Emma Thompson give good performances with southern/New Orleans accents in this detective flick. It's worth seeing for their scenes- and Rickman's scene with Hal Holbrook. These three actors mannage to entertain us no matter what the movie, it seems. The plot for the movie shows potential, but one gets the impression in watching the film that it was not pulled off as well as it could have been. The fact that it is cluttered by a rather uninteresting subplot and mostly uninteresting kidnappers really muddles things. The movie is worth a view- if for nothing more than entertaining performances by Rickman, Thompson, and Holbrook."}

# %% [markdown]
# Next, we build a function `feature_function()` that annotates datasets with feature vectors.

# %%
def feature_function(datasets):
    '''Annotates datasets with feature vectors.'''
                         
    # Extract vocabulary
    def tokenize(string):
        return string.split()
    
    word_counter = collections.Counter()
    for example in datasets[0]:
        word_counter.update(tokenize(example['text']))
    
    vocabulary = set([word for word in word_counter])

    feature_names = set()
    for i, dataset in enumerate(datasets):
        for example in dataset:
            example['features'] = collections.defaultdict(float)
        
            
            #Extract features (by name) for one example:
            word_counter = collections.Counter(tokenize(example['text']))
            for x in word_counter.items():
                if x[0] in vocabulary:
                    example["features"]["word_count_for_" + x[0]] = min(x[1], 1)
                    
#            '''
#                Adding Negation feature
#            '''        
#             if "n't" in example['text'] or "not" in example['text']:
#                 example["features"]["negation"] = 1
#             else:
#                 example["features"]["negation"] = 0
            
            feature_names.update(example['features'].keys())
                            
    # By now, we know what all the features will be, so we can
    # assign indices to them.
    feature_indices = dict(zip(feature_names, range(len(feature_names))))
    indices_to_features = {v: k for k, v in feature_indices.items()}
    dim = len(feature_indices)
                
    # Now we create actual vectors from those indices.
    for dataset in datasets:
        for example in dataset:
            example['vector'] = np.zeros((dim))
            for feature in example['features']:
                example['vector'][feature_indices[feature]] = example['features'][feature]
    return indices_to_features
    
indices_to_features = feature_function([training_set, dev_set, imdb_test])

# %%
indices_to_features
# Out:
# {0: 'word_count_for_boredom',
#  1: 'word_count_for_peppered',
#  2: 'word_count_for_spinoff',
#  3: 'word_count_for_denouements',
#  4: 'word_count_for_Branagh',
#  5: 'word_count_for_teenager',
#  6: 'word_count_for_fabulous',
#  7: 'word_count_for_Demi',
#  8: 'word_count_for_minutes',
#  9: 'word_count_for_categorize',
#  10: 'word_count_for_pacing',
#  11: 'word_count_for_Bullock',
#  12: 'word_count_for_exchanges',
#  13: 'word_count_for_ghastly',
#  14: 'word_count_for_Nightmare',
#  15: 'word_count_for_heady',
#  16: 'word_count_for_shattering',
#  17: 'word_count_for_2000',
#  18: 'word_count_for_thumbs',
#  19: 'word_count_for_bonds',
#  20: 'word_count_for_rarest',
#  21: 'word_count_for_intent',
#  22: 'word_count_for_stench',
#  23: 'word_count_for_Songs',
#  24: 'word_count_for_doorstep',
#  25: 'word_count_for_together',
#  26: 'word_count_for_changes',
#  27: 'word_count_for_Sayles',
#  28: 'word_count_for_sheer',
#  29: 'word_count_for_juiced',
#  30: 'word_count_for_makes',
#  31: 'word_count_for_confidence',
#  32: 'word_count_for_unnoticed',
#  33: 'word_count_for_sensation',
#  34: 'word_count_for_literarily',
#  35: 'word_count_for_95',
#  36: 'word_count_for_Highlighted',
#  37: 'word_count_for_ring',
#  38: 'word_count_for_Performances',
#  39: 'word_count_for_crisp',
#  40: 'word_count_for_fuses',
#  41: 'word_count_for_candidate',
#  42: 'word_count_for_Falsehoods',
#  43: 'word_count_for_well-made',
#  44: 'word_count_for_slow-motion',
#  45: 'word_count_for_burdened',
#  46: 'word_count_for_Insanely',
#  47: 'word_count_for_Ace',
#  48: 'word_count_for_pathos',
#  49: 'word_count_for_grating',
#  50: 'word_count_for_after-school',
#  51: 'word_count_for_Formula',
#  52: 'word_count_for_preposterousness',
#  53: 'word_count_for_message',
#  54: 'word_count_for_Age',
#  55: 'word_count_for_task',
#  56: 'word_count_for_exotic',
#  57: 'word_count_for_Prophecies',
#  58: 'word_count_for_big-hearted',
#  59: 'word_count_for_Middle-earth',
#  60: 'word_count_for_muddy',
#  61: 'word_count_for_crescendo',
#  62: 'word_count_for_procedure',
#  63: 'word_count_for_Sunshine',
#  64: 'word_count_for_empowerment',
#  65: 'word_count_for_cranked',
#  66: 'word_count_for_worship',
#  67: 'word_count_for_wobbly',
#  68: 'word_count_for_Conrad',
#  69: 'word_count_for_commentary',
#  70: 'word_count_for_drying',
#  71: 'word_count_for_Secrets',
#  72: 'word_count_for_dress',
#  73: 'word_count_for_I',
#  74: 'word_count_for_sell',
#  75: 'word_count_for_escapes',
#  76: 'word_count_for_gored',
#  77: 'word_count_for_limit',
#  78: 'word_count_for_old-fashioned',
#  79: 'word_count_for_portrayal',
#  80: 'word_count_for_overdoing',
#  81: 'word_count_for_fizzle',
#  82: 'word_count_for_surrealist',
#  83: 'word_count_for_Joffé',
#  84: 'word_count_for_ministers',
#  85: 'word_count_for_Ringu',
#  86: 'word_count_for_begun',
#  87: 'word_count_for_Burning',
#  88: 'word_count_for_pork',
#  89: 'word_count_for_complete',
#  90: 'word_count_for_backlash',
#  91: 'word_count_for_meal',
#  92: 'word_count_for_satisfies',
#  93: 'word_count_for_vocalized',
#  94: 'word_count_for_Serry',
#  95: 'word_count_for_unencouraging',
#  96: 'word_count_for_flck',
#  97: 'word_count_for_agitator',
#  98: 'word_count_for_eyes',
#  99: 'word_count_for_Kingsley',
#  100: 'word_count_for_herrings',
#  101: 'word_count_for_ill-equipped',
#  102: 'word_count_for_Mean',
#  103: 'word_count_for_stress-reducing',
#  104: 'word_count_for_charming',
#  105: 'word_count_for_nail-biter',
#  106: 'word_count_for_waking',
#  107: 'word_count_for_crassly',
#  108: 'word_count_for_definitely',
#  109: 'word_count_for_enhances',
#  110: 'word_count_for_dishonest',
#  111: 'word_count_for_unprecedented',
#  112: 'word_count_for_Grey',
#  113: 'word_count_for_Sullivan',
#  114: 'word_count_for_much-needed',
#  115: 'word_count_for_unabashedly',
#  116: 'word_count_for_foul',
#  117: 'word_count_for_remembrance',
#  118: 'word_count_for_punch',
#  119: 'word_count_for_disguise',
#  120: 'word_count_for_Reyes',
#  121: 'word_count_for_deviant',
#  122: 'word_count_for_welcome',
#  123: 'word_count_for_fighting',
#  124: 'word_count_for_Bartleby',
#  125: 'word_count_for_visualize',
#  126: 'word_count_for_telephone',
#  127: 'word_count_for_Sever',
#  128: 'word_count_for_McDormand',
#  129: 'word_count_for_wayward',
#  130: 'word_count_for_scooping',
#  131: 'word_count_for_commended',
#  132: 'word_count_for_shortcomings',
#  133: 'word_count_for_behave',
#  134: 'word_count_for_paranoid',
#  135: 'word_count_for_depth',
#  136: 'word_count_for_arrive',
#  137: 'word_count_for_Warner',
#  138: 'word_count_for_Brazil-like',
#  139: 'word_count_for_symbols',
#  140: 'word_count_for_cut-and-paste',
#  141: 'word_count_for_dorkier',
#  142: 'word_count_for_older',
#  143: 'word_count_for_informed',
#  144: 'word_count_for_delicately',
#  145: 'word_count_for_Silly',
#  146: 'word_count_for_instructs',
#  147: 'word_count_for_cushion',
#  148: 'word_count_for_blue',
#  149: 'word_count_for_batting',
#  150: 'word_count_for_S',
#  151: 'word_count_for_assassination',
#  152: 'word_count_for_exude',
#  153: 'word_count_for_showcase',
#  154: 'word_count_for_length',
#  155: 'word_count_for_Things',
#  156: 'word_count_for_add',
#  157: 'word_count_for_daydreams',
#  158: 'word_count_for_lobotomy',
#  159: 'word_count_for_hope',
#  160: 'word_count_for_picture',
#  161: 'word_count_for_colleagues',
#  162: 'word_count_for_Næss',
#  163: 'word_count_for_Winds',
#  164: 'word_count_for_excuse',
#  165: 'word_count_for_thorough',
#  166: 'word_count_for_Picture',
#  167: 'word_count_for_addition',
#  168: 'word_count_for_Decasia',
#  169: 'word_count_for_charge',
#  170: 'word_count_for_dare',
#  171: 'word_count_for_throw',
#  172: 'word_count_for_gurus',
#  173: 'word_count_for_Limit',
#  174: 'word_count_for_fluttering',
#  175: 'word_count_for_achievement',
#  176: 'word_count_for_escapades',
#  177: 'word_count_for_underappreciated',
#  178: 'word_count_for_24\\/7',
#  179: 'word_count_for_lifetime',
#  180: 'word_count_for_Refreshing',
#  181: 'word_count_for_pub',
#  182: 'word_count_for_acceptance',
#  183: 'word_count_for_Perry',
#  184: 'word_count_for_amused',
#  185: 'word_count_for_washed',
#  186: 'word_count_for_moviemakers',
#  187: 'word_count_for_Claude',
#  188: 'word_count_for_sentence',
#  189: 'word_count_for_multi-layered',
#  190: 'word_count_for_rats',
#  191: 'word_count_for_percentages',
#  192: 'word_count_for_Jacobi',
#  193: 'word_count_for_hardware',
#  194: 'word_count_for_clamoring',
#  195: 'word_count_for_risk',
#  196: 'word_count_for_romanced',
#  197: 'word_count_for_plumbs',
#  198: 'word_count_for_consistent',
#  199: 'word_count_for_heavyweight',
#  200: 'word_count_for_Pixar',
#  201: 'word_count_for_bloodbath',
#  202: 'word_count_for_emphasis',
#  203: 'word_count_for_car',
#  204: 'word_count_for_rate',
#  205: 'word_count_for_terribly',
#  206: 'word_count_for_Simpsons',
#  207: 'word_count_for_pushiness',
#  208: 'word_count_for_Charlotte',
#  209: 'word_count_for_save',
#  210: 'word_count_for_luckiest',
#  211: 'word_count_for_If',
#  212: 'word_count_for_press',
#  213: 'word_count_for_produced',
#  214: 'word_count_for_guilt-trip',
#  215: 'word_count_for_Kramer',
#  216: 'word_count_for_Jet',
#  217: 'word_count_for_piecing',
#  218: 'word_count_for_comics',
#  219: 'word_count_for_hipness',
#  220: 'word_count_for_drawing',
#  221: 'word_count_for_goose',
#  222: 'word_count_for_goofiest',
#  223: 'word_count_for_remind',
#  224: 'word_count_for_tend',
#  225: 'word_count_for_heck',
#  226: 'word_count_for_w',
#  227: 'word_count_for_self-important',
#  228: 'word_count_for_pretends',
#  229: 'word_count_for_nihilistic',
#  230: 'word_count_for_Aan',
#  231: 'word_count_for_Kirsten',
#  232: 'word_count_for_Reese',
#  233: 'word_count_for_Lambs',
#  234: 'word_count_for_servants',
#  235: 'word_count_for_makers',
#  236: 'word_count_for_soothe',
#  237: 'word_count_for_defines',
#  238: 'word_count_for_skillful',
#  239: 'word_count_for_hook',
#  240: 'word_count_for_animé',
#  241: 'word_count_for_lending',
#  242: 'word_count_for_Texan',
#  243: 'word_count_for_reshaping',
#  244: 'word_count_for_action-adventure',
#  245: 'word_count_for_molehill',
#  246: 'word_count_for_duck',
#  247: 'word_count_for_forgot',
#  248: 'word_count_for_hypnotic',
#  249: 'word_count_for_principles',
#  250: 'word_count_for_Past',
#  251: 'word_count_for_fame',
#  252: 'word_count_for_please',
#  253: 'word_count_for_Shu',
#  254: 'word_count_for_clothing',
#  255: 'word_count_for_cover',
#  256: 'word_count_for_small-scale',
#  257: 'word_count_for_Fiennes',
#  258: 'word_count_for_honesty',
#  259: 'word_count_for_produces',
#  260: 'word_count_for_anchor',
#  261: 'word_count_for_decades-spanning',
#  262: 'word_count_for_movies',
#  263: 'word_count_for_passionately',
#  264: 'word_count_for_deer',
#  265: 'word_count_for_classics',
#  266: 'word_count_for_pasty',
#  267: 'word_count_for_extrusion',
#  268: 'word_count_for_Lina',
#  269: 'word_count_for_rather',
#  270: 'word_count_for_satisfying',
#  271: 'word_count_for_payoff',
#  272: 'word_count_for_Gives',
#  273: 'word_count_for_baroque',
#  274: 'word_count_for_swirl',
#  275: 'word_count_for_plex',
#  276: 'word_count_for_curiosity',
#  277: 'word_count_for_hard-partying',
#  278: 'word_count_for_sixties',
#  279: 'word_count_for_indulgent',
#  280: 'word_count_for_hotel',
#  281: 'word_count_for_spicy',
#  282: 'word_count_for_Warriors',
#  283: 'word_count_for_adjusting',
#  284: 'word_count_for_stirring',
#  285: 'word_count_for_specifics',
#  286: 'word_count_for_fault',
#  287: 'word_count_for_Ferris',
#  288: 'word_count_for_sketchiest',
#  289: 'word_count_for_squirming',
#  290: 'word_count_for_Co-writer\\/director',
#  291: 'word_count_for_reverent',
#  292: 'word_count_for_boost',
#  293: 'word_count_for_non-Disney',
#  294: 'word_count_for_telescope',
#  295: 'word_count_for_9-11',
#  296: 'word_count_for_contrast',
#  297: 'word_count_for_competent',
#  298: 'word_count_for_spectacle',
#  299: 'word_count_for_Dahmer',
#  300: 'word_count_for_Irwin',
#  301: 'word_count_for_mishmash',
#  302: 'word_count_for_far-flung',
#  303: 'word_count_for_blown-out',
#  304: 'word_count_for_unmentionables',
#  305: 'word_count_for_establishes',
#  306: 'word_count_for_strands',
#  307: 'word_count_for_agreeably',
#  308: 'word_count_for_imagine',
#  309: 'word_count_for_conveys',
#  310: 'word_count_for_Showtime',
#  311: 'word_count_for_bid',
#  312: 'word_count_for_Savoca',
#  313: 'word_count_for_saddens',
#  314: 'word_count_for_asparagus',
#  315: 'word_count_for_1970',
#  316: 'word_count_for_running',
#  317: 'word_count_for_splitting',
#  318: 'word_count_for_practical',
#  319: 'word_count_for_Pacino',
#  320: 'word_count_for_expressions',
#  321: 'word_count_for_consequences',
#  322: 'word_count_for_Clare',
#  323: 'word_count_for_performed',
#  324: 'word_count_for_DVD',
#  325: 'word_count_for_Hjelje',
#  326: 'word_count_for_89',
#  327: 'word_count_for_forgotten',
#  328: 'word_count_for_short',
#  329: 'word_count_for_graced',
#  330: 'word_count_for_animation',
#  331: 'word_count_for_spaniel-eyed',
#  332: 'word_count_for_transported',
#  333: 'word_count_for_ces',
#  334: 'word_count_for_Victor',
#  335: 'word_count_for_dodges',
#  336: 'word_count_for_Hicks',
#  337: 'word_count_for_counts',
#  338: 'word_count_for_grossly',
#  339: 'word_count_for_fantasies',
#  340: 'word_count_for_prowess',
#  341: 'word_count_for_lip-reading',
#  342: 'word_count_for_chatter',
#  343: 'word_count_for_Walter',
#  344: 'word_count_for_168-minute',
#  345: 'word_count_for_accumulated',
#  346: 'word_count_for_floating',
#  347: 'word_count_for_break',
#  348: 'word_count_for_surrounds',
#  349: 'word_count_for_Sets',
#  350: 'word_count_for_spree',
#  351: 'word_count_for_fifth',
#  352: 'word_count_for_wind',
#  353: 'word_count_for_finish',
#  354: 'word_count_for_Jackie',
#  355: 'word_count_for_character',
#  356: 'word_count_for_happiness',
#  357: 'word_count_for_Philip',
#  358: 'word_count_for_shimmeringly',
#  359: 'word_count_for_Pie',
#  360: 'word_count_for_sleazy',
#  361: 'word_count_for_Pogue',
#  362: 'word_count_for_Mexico',
#  363: 'word_count_for_ailments',
#  364: 'word_count_for_mobility',
#  365: 'word_count_for_saves',
#  366: 'word_count_for_sickeningly',
#  367: 'word_count_for_celebrate',
#  368: 'word_count_for_dreamscape',
#  369: 'word_count_for_surge',
#  370: 'word_count_for_Ben',
#  371: 'word_count_for_included',
#  372: 'word_count_for_Cheese',
#  373: 'word_count_for_smart-aleck',
#  374: 'word_count_for_Bland',
#  375: 'word_count_for_commenting',
#  376: 'word_count_for_Plodding',
#  377: 'word_count_for_Photo',
#  378: 'word_count_for_relationships',
#  379: 'word_count_for_uninventive',
#  380: 'word_count_for_eccentric',
#  381: 'word_count_for_Taymor',
#  382: 'word_count_for_protagonists',
#  383: 'word_count_for_church',
#  384: 'word_count_for_best',
#  385: 'word_count_for_animaton',
#  386: 'word_count_for_Staggeringly',
#  387: 'word_count_for_C.H.O.',
#  388: 'word_count_for_Cherish',
#  389: 'word_count_for_Apparently',
#  390: 'word_count_for_Villeneuve',
#  391: 'word_count_for_entertained',
#  392: 'word_count_for_marveilleux',
#  393: 'word_count_for_wasted',
#  394: 'word_count_for_Wiel',
#  395: 'word_count_for_parking',
#  396: 'word_count_for_sleaziness',
#  397: 'word_count_for_sincere',
#  398: 'word_count_for_merited',
#  399: 'word_count_for_sprinkled',
#  400: 'word_count_for_combustible',
#  401: 'word_count_for_Nearly',
#  402: 'word_count_for_tenderly',
#  403: 'word_count_for_Gregory',
#  404: 'word_count_for_Auteil',
#  405: 'word_count_for_unified',
#  406: 'word_count_for_unexplainable',
#  407: 'word_count_for_Sonny',
#  408: 'word_count_for_journalistic',
#  409: 'word_count_for_unchanged',
#  410: 'word_count_for_so-called',
#  411: 'word_count_for_believe',
#  412: 'word_count_for_Public',
#  413: 'word_count_for_conclusion',
#  414: 'word_count_for_Mexican',
#  415: 'word_count_for_Herzog',
#  416: 'word_count_for_Secretary',
#  417: 'word_count_for_undeniably',
#  418: 'word_count_for_Told',
#  419: 'word_count_for_table',
#  420: 'word_count_for_handful',
#  421: 'word_count_for_pathology',
#  422: 'word_count_for_heartily',
#  423: 'word_count_for_infrequently',
#  424: 'word_count_for_Roberts',
#  425: 'word_count_for_protestors',
#  426: 'word_count_for_rhythms',
#  427: 'word_count_for_melancholy',
#  428: 'word_count_for_strategies',
#  429: 'word_count_for_baboon',
#  430: 'word_count_for_culled',
#  431: 'word_count_for_travails',
#  432: 'word_count_for_Hence',
#  433: 'word_count_for_bustling',
#  434: 'word_count_for_does',
#  435: 'word_count_for_epitaph',
#  436: 'word_count_for_qatsi',
#  437: 'word_count_for_malapropisms',
#  438: 'word_count_for_Hawley',
#  439: 'word_count_for_wo',
#  440: 'word_count_for_ensure',
#  441: 'word_count_for_Where',
#  442: 'word_count_for_fuel',
#  443: 'word_count_for_Diaz',
#  444: 'word_count_for_capped',
#  445: 'word_count_for_sin',
#  446: 'word_count_for_Notting',
#  447: 'word_count_for_suppression',
#  448: 'word_count_for_nouvelle',
#  449: 'word_count_for_delights',
#  450: 'word_count_for_Jordan',
#  451: 'word_count_for_sought',
#  452: 'word_count_for_round',
#  453: 'word_count_for_array',
#  454: 'word_count_for_loathsome',
#  455: 'word_count_for_vowing',
#  456: 'word_count_for_all-woman',
#  457: 'word_count_for_enlivens',
#  458: 'word_count_for_cautions',
#  459: 'word_count_for_buffs',
#  460: 'word_count_for_on-screen',
#  461: 'word_count_for_astounds',
#  462: 'word_count_for_Food',
#  463: 'word_count_for_Choices',
#  464: 'word_count_for_unread',
#  465: 'word_count_for_holographic',
#  466: 'word_count_for_Lyne',
#  467: 'word_count_for_elusive',
#  468: 'word_count_for_tear',
#  469: 'word_count_for_Y',
#  470: 'word_count_for_betters',
#  471: 'word_count_for_decidedly',
#  472: 'word_count_for_headbanger',
#  473: 'word_count_for_Crystal',
#  474: 'word_count_for_explosions',
#  475: 'word_count_for_guises',
#  476: 'word_count_for_leaky',
#  477: 'word_count_for_self-satisfied',
#  478: 'word_count_for_gullets',
#  479: 'word_count_for_labyrinthine',
#  480: 'word_count_for_War',
#  481: 'word_count_for_Liman',
#  482: 'word_count_for_Smarter',
#  483: 'word_count_for_beyond-lame',
#  484: 'word_count_for_Best',
#  485: 'word_count_for_gold',
#  486: 'word_count_for_throwaway',
#  487: "word_count_for_'60s",
#  488: 'word_count_for_Johnny',
#  489: 'word_count_for_Singles',
#  490: 'word_count_for_unfakable',
#  491: 'word_count_for_Otar',
#  492: 'word_count_for_nonchalant',
#  493: 'word_count_for_asks',
#  494: 'word_count_for_M.',
#  495: 'word_count_for_adds',
#  496: 'word_count_for_reached',
#  497: 'word_count_for_re',
#  498: 'word_count_for_videotape',
#  499: 'word_count_for_damage',
#  500: 'word_count_for_cringe',
#  501: 'word_count_for_sides',
#  502: 'word_count_for_Its',
#  503: 'word_count_for_metal',
#  504: 'word_count_for_distinction',
#  505: 'word_count_for_Shrewd',
#  506: 'word_count_for_cunning',
#  507: 'word_count_for_surface-obsession',
#  508: 'word_count_for_commend',
#  509: 'word_count_for_smarter',
#  510: 'word_count_for_affection',
#  511: 'word_count_for_beacon',
#  512: 'word_count_for_lowbrow',
#  513: 'word_count_for_right-wing',
#  514: 'word_count_for_unfunny',
#  515: 'word_count_for_T.',
#  516: 'word_count_for_tackling',
#  517: 'word_count_for_sweetly',
#  518: 'word_count_for_effectiveness',
#  519: 'word_count_for_Reaches',
#  520: 'word_count_for_recipe',
#  521: 'word_count_for_fuels',
#  522: 'word_count_for_yearnings',
#  523: 'word_count_for_sluggish',
#  524: 'word_count_for_kitchen-sink',
#  525: 'word_count_for_predictable',
#  526: 'word_count_for_Banzai',
#  527: 'word_count_for_conundrum',
#  528: 'word_count_for_updating',
#  529: 'word_count_for_irresistible',
#  530: 'word_count_for_construct',
#  531: 'word_count_for_betrayed',
#  532: 'word_count_for_Lovingly',
#  533: 'word_count_for_Koury',
#  534: 'word_count_for_Maggio',
#  535: 'word_count_for_melancholia',
#  536: 'word_count_for_lushly',
#  537: 'word_count_for_daytime-drama',
#  538: 'word_count_for_melancholic',
#  539: 'word_count_for_star-power',
#  540: 'word_count_for_map',
#  541: 'word_count_for_shaking',
#  542: 'word_count_for_painkillers',
#  543: 'word_count_for_fascinates',
#  544: 'word_count_for_eloquently',
#  545: 'word_count_for_lower-class',
#  546: 'word_count_for_dead-on',
#  547: 'word_count_for_perfectly',
#  548: 'word_count_for_million',
#  549: 'word_count_for_harrowing',
#  550: 'word_count_for_copout',
#  551: 'word_count_for_releasing',
#  552: 'word_count_for_viewers',
#  553: 'word_count_for_massive',
#  554: 'word_count_for_befuddled',
#  555: 'word_count_for_live',
#  556: 'word_count_for_random',
#  557: 'word_count_for_Holm',
#  558: 'word_count_for_kiddie-oriented',
#  559: 'word_count_for_neck',
#  560: 'word_count_for_fumbled',
#  561: 'word_count_for_largest-ever',
#  562: 'word_count_for_Davis',
#  563: 'word_count_for_grey',
#  564: 'word_count_for_unsalvageability',
#  565: 'word_count_for_Toback',
#  566: 'word_count_for_Cook',
#  567: 'word_count_for_McCoist',
#  568: 'word_count_for_mysteries',
#  569: 'word_count_for_Kurds',
#  570: 'word_count_for_resides',
#  571: 'word_count_for_experiment',
#  572: 'word_count_for_grace',
#  573: 'word_count_for_Basketball',
#  574: 'word_count_for_pleas',
#  575: 'word_count_for_loyalty',
#  576: 'word_count_for_music',
#  577: 'word_count_for_surprises',
#  578: 'word_count_for_medical',
#  579: 'word_count_for_guilt',
#  580: 'word_count_for_plasma',
#  581: 'word_count_for_peopled',
#  582: 'word_count_for_unlikeable',
#  583: 'word_count_for_implications',
#  584: 'word_count_for_Sugarman',
#  585: 'word_count_for_exercises',
#  586: 'word_count_for_siren',
#  587: 'word_count_for_rigidly',
#  588: 'word_count_for_Sleeper',
#  589: 'word_count_for_switches',
#  590: 'word_count_for_disagree',
#  591: 'word_count_for_Xmas',
#  592: 'word_count_for_surfeit',
#  593: 'word_count_for_hubristic',
#  594: 'word_count_for_Grating',
#  595: 'word_count_for_multiple',
#  596: 'word_count_for_context',
#  597: 'word_count_for_scarier',
#  598: 'word_count_for_understands',
#  599: 'word_count_for_oftentimes',
#  600: 'word_count_for_heartening',
#  601: "word_count_for_'90s",
#  602: 'word_count_for_do',
#  603: 'word_count_for_countless',
#  604: 'word_count_for_relaxed',
#  605: 'word_count_for_participants',
#  606: 'word_count_for_sexuality',
#  607: 'word_count_for_delivering',
#  608: 'word_count_for_assembles',
#  609: 'word_count_for_dresses',
#  610: 'word_count_for_liking',
#  611: 'word_count_for_luck',
#  612: 'word_count_for_Fathers',
#  613: 'word_count_for_hangover',
#  614: 'word_count_for_Hate',
#  615: 'word_count_for_tale',
#  616: 'word_count_for_harvesting',
#  617: 'word_count_for_lines',
#  618: 'word_count_for_co-dependence',
#  619: 'word_count_for_Shatner',
#  620: 'word_count_for_dosage',
#  621: 'word_count_for_Earnest',
#  622: 'word_count_for_dawdle',
#  623: 'word_count_for_off',
#  624: 'word_count_for_outdoes',
#  625: 'word_count_for_bombshell',
#  626: 'word_count_for_thinly-conceived',
#  627: 'word_count_for_humanist',
#  628: 'word_count_for_democracie',
#  629: 'word_count_for_articulate',
#  630: 'word_count_for_homicide',
#  631: 'word_count_for_undertaken',
#  632: 'word_count_for_ransacked',
#  633: 'word_count_for_witty',
#  634: 'word_count_for_mall',
#  635: 'word_count_for_Fortune',
#  636: 'word_count_for_mushy',
#  637: 'word_count_for_jarring',
#  638: 'word_count_for_alluring',
#  639: 'word_count_for_pitch',
#  640: 'word_count_for_Becomes',
#  641: 'word_count_for_power-lunchers',
#  642: 'word_count_for_resentment',
#  643: 'word_count_for_demented-funny',
#  644: 'word_count_for_atmospherics',
#  645: 'word_count_for_Breillat',
#  646: 'word_count_for_full-fledged',
#  647: 'word_count_for_classified',
#  648: 'word_count_for_stylistically',
#  649: 'word_count_for_flash',
#  650: 'word_count_for_Plot',
#  651: 'word_count_for_partner',
#  652: 'word_count_for_moon',
#  653: 'word_count_for_repeating',
#  654: 'word_count_for_Ignore',
#  655: 'word_count_for_collapse',
#  656: 'word_count_for_authority',
#  657: 'word_count_for_hard-pressed',
#  658: 'word_count_for_why',
#  659: 'word_count_for_specter',
#  660: 'word_count_for_cleverly',
#  661: 'word_count_for_chuckling',
#  662: 'word_count_for_Buy',
#  663: 'word_count_for_insane',
#  664: 'word_count_for_greasy',
#  665: 'word_count_for_Resembles',
#  666: 'word_count_for_barbarism',
#  667: 'word_count_for_laughs',
#  668: 'word_count_for_photographed',
#  669: 'word_count_for_star-studded',
#  670: 'word_count_for_Oscar-worthy',
#  671: 'word_count_for_Hush',
#  672: 'word_count_for_concern',
#  673: 'word_count_for_pre-credit',
#  674: 'word_count_for_Stevenson',
#  675: 'word_count_for_Sixth',
#  676: 'word_count_for_filled',
#  677: 'word_count_for_swept',
#  678: 'word_count_for_undead',
#  679: 'word_count_for_They',
#  680: 'word_count_for_obstacles',
#  681: 'word_count_for_Next',
#  682: 'word_count_for_Killing',
#  683: 'word_count_for_achievements',
#  684: 'word_count_for_ransacks',
#  685: 'word_count_for_Assured',
#  686: 'word_count_for_1975',
#  687: 'word_count_for_outweighs',
#  688: 'word_count_for_cause',
#  689: 'word_count_for_Rodrigues',
#  690: 'word_count_for_People',
#  691: 'word_count_for_choppy',
#  692: 'word_count_for_ditched',
#  693: 'word_count_for_writer-producer-director',
#  694: 'word_count_for_racist',
#  695: 'word_count_for_amazing',
#  696: 'word_count_for_impersonal',
#  697: 'word_count_for_reconstruction',
#  698: 'word_count_for_Ken',
#  699: 'word_count_for_drag',
#  700: 'word_count_for_dozens',
#  701: 'word_count_for_hail',
#  702: 'word_count_for_communal',
#  703: 'word_count_for_wish',
#  704: 'word_count_for_super-sized',
#  705: 'word_count_for_Roy',
#  706: 'word_count_for_utter',
#  707: 'word_count_for_dullard',
#  708: 'word_count_for_decline',
#  709: 'word_count_for_parables',
#  710: 'word_count_for_cinematic',
#  711: 'word_count_for_excite',
#  712: 'word_count_for_documentary-making',
#  713: 'word_count_for_remembering',
#  714: 'word_count_for_plans',
#  715: 'word_count_for_sum',
#  716: 'word_count_for_low-wattage',
#  717: 'word_count_for_well-structured',
#  718: 'word_count_for_antiseptic',
#  719: 'word_count_for_Handled',
#  720: 'word_count_for_Haynes',
#  721: 'word_count_for_subplot',
#  722: 'word_count_for_prefabricated',
#  723: 'word_count_for_Mark',
#  724: 'word_count_for_sleeve',
#  725: 'word_count_for_hormonal',
#  726: "word_count_for_O'Fallon",
#  727: 'word_count_for_tragic',
#  728: 'word_count_for_Columbine',
#  729: 'word_count_for_quality',
#  730: 'word_count_for_law',
#  731: 'word_count_for_old-time',
#  732: 'word_count_for_post-September',
#  733: 'word_count_for_Gaye',
#  734: 'word_count_for_delusions',
#  735: 'word_count_for_mine',
#  736: 'word_count_for_moviegoing',
#  737: 'word_count_for_topic',
#  738: 'word_count_for_rising',
#  739: 'word_count_for_monument',
#  740: 'word_count_for_Sandeman',
#  741: 'word_count_for_Excellent',
#  742: 'word_count_for_humanistic',
#  743: 'word_count_for_Tommy',
#  744: 'word_count_for_remarkable',
#  745: 'word_count_for_campaign-trail',
#  746: 'word_count_for_undertone',
#  747: 'word_count_for_depths',
#  748: 'word_count_for_well-paced',
#  749: 'word_count_for_Lips',
#  750: 'word_count_for_insufficiently',
#  751: 'word_count_for_smash',
#  752: 'word_count_for_Christelle',
#  753: 'word_count_for_launching',
#  754: 'word_count_for_Christianity',
#  755: 'word_count_for_displays',
#  756: 'word_count_for_4',
#  757: 'word_count_for_career-best',
#  758: 'word_count_for_usually',
#  759: 'word_count_for_products',
#  760: 'word_count_for_Latino',
#  761: 'word_count_for_doings',
#  762: 'word_count_for_Personally',
#  763: 'word_count_for_squarely',
#  764: 'word_count_for_afterschool',
#  765: 'word_count_for_deliberative',
#  766: 'word_count_for_practically',
#  767: 'word_count_for_very',
#  768: 'word_count_for_trudge',
#  769: 'word_count_for_También',
#  770: 'word_count_for_Huppert',
#  771: 'word_count_for_icon',
#  772: 'word_count_for_undramatic',
#  773: 'word_count_for_byways',
#  774: 'word_count_for_gutter',
#  775: 'word_count_for_unforced',
#  776: 'word_count_for_trotting',
#  777: 'word_count_for_whodunit',
#  778: 'word_count_for_upbeat',
#  779: 'word_count_for_Boy',
#  780: 'word_count_for_influence',
#  781: 'word_count_for_screenings',
#  782: 'word_count_for_status',
#  783: 'word_count_for_European',
#  784: 'word_count_for_toes',
#  785: 'word_count_for_alter',
#  786: 'word_count_for_bump',
#  787: 'word_count_for_chaotic',
#  788: 'word_count_for_tomfoolery',
#  789: 'word_count_for_treated',
#  790: 'word_count_for_real-life',
#  791: 'word_count_for_were',
#  792: 'word_count_for_comical',
#  793: 'word_count_for_sounding',
#  794: 'word_count_for_stare',
#  795: 'word_count_for_last',
#  796: 'word_count_for_incapable',
#  797: 'word_count_for_unconvincing',
#  798: 'word_count_for_pained',
#  799: 'word_count_for_recite',
#  800: 'word_count_for_leap',
#  801: 'word_count_for_repetitively',
#  802: 'word_count_for_uncluttered',
#  803: 'word_count_for_Mai',
#  804: 'word_count_for_reality',
#  805: 'word_count_for_Moore',
#  806: 'word_count_for_African-Americans',
#  807: 'word_count_for_sudden',
#  808: 'word_count_for_EEE',
#  809: 'word_count_for_Knows',
#  810: 'word_count_for_exposition',
#  811: 'word_count_for_touching',
#  812: 'word_count_for_devastating',
#  813: 'word_count_for_Rorschach',
#  814: 'word_count_for_Throw',
#  815: 'word_count_for_hysteria',
#  816: 'word_count_for_Their',
#  817: 'word_count_for_ties',
#  818: 'word_count_for_simpleminded',
#  819: 'word_count_for_formidable',
#  820: 'word_count_for_spells',
#  821: 'word_count_for_vacuous',
#  822: 'word_count_for_stylish',
#  823: 'word_count_for_excels',
#  824: 'word_count_for_picked',
#  825: 'word_count_for_traces',
#  826: 'word_count_for_haul',
#  827: 'word_count_for_also',
#  828: 'word_count_for_strength',
#  829: 'word_count_for_self-absorption',
#  830: 'word_count_for_padding',
#  831: 'word_count_for_cribbing',
#  832: 'word_count_for_howlingly',
#  833: 'word_count_for_Beautiful',
#  834: 'word_count_for_Teddy',
#  835: 'word_count_for_Schaeffer',
#  836: 'word_count_for_restroom',
#  837: 'word_count_for_pain',
#  838: 'word_count_for_ahead',
#  839: 'word_count_for_wonder',
#  840: 'word_count_for_verismo',
#  841: 'word_count_for_However',
#  842: 'word_count_for_willingness',
#  843: 'word_count_for_adventures',
#  844: 'word_count_for_captivates',
#  845: 'word_count_for_salaries',
#  846: 'word_count_for_consigned',
#  847: 'word_count_for_smashups',
#  848: 'word_count_for_awry',
#  849: 'word_count_for_Morris',
#  850: 'word_count_for_triumph',
#  851: 'word_count_for_libretto',
#  852: 'word_count_for_louts',
#  853: 'word_count_for_sympathies',
#  854: 'word_count_for_zero',
#  855: 'word_count_for_giddy',
#  856: 'word_count_for_ascertain',
#  857: 'word_count_for_instilled',
#  858: 'word_count_for_meshes',
#  859: 'word_count_for_50-year-old',
#  860: 'word_count_for_Elie',
#  861: 'word_count_for_invokes',
#  862: 'word_count_for_shoe-loving',
#  863: 'word_count_for_leaps',
#  864: 'word_count_for_biggest',
#  865: 'word_count_for_plus',
#  866: 'word_count_for_dumped',
#  867: 'word_count_for_Billy',
#  868: 'word_count_for_undeterminable',
#  869: 'word_count_for_elliptically',
#  870: 'word_count_for_machines',
#  871: 'word_count_for_Tarantino',
#  872: 'word_count_for_retains',
#  873: 'word_count_for_thankfully',
#  874: 'word_count_for_recount',
#  875: 'word_count_for_conspiratorial',
#  876: 'word_count_for_eager',
#  877: 'word_count_for_impenetrable',
#  878: 'word_count_for_boiled',
#  879: 'word_count_for_overflows',
#  880: 'word_count_for_luridly',
#  881: 'word_count_for_provoked',
#  882: 'word_count_for_questionable',
#  883: 'word_count_for_manners',
#  884: 'word_count_for_minor-league',
#  885: 'word_count_for_minutely',
#  886: 'word_count_for_Vereté',
#  887: 'word_count_for_Date',
#  888: 'word_count_for_prints',
#  889: 'word_count_for_Jay',
#  890: 'word_count_for_deal',
#  891: 'word_count_for_gamesmanship',
#  892: 'word_count_for_leaning',
#  893: 'word_count_for_House',
#  894: 'word_count_for_Dalloway',
#  895: 'word_count_for_commune',
#  896: 'word_count_for_outsiders',
#  897: 'word_count_for_supremely',
#  898: 'word_count_for_overview',
#  899: 'word_count_for_idea',
#  900: 'word_count_for_voice',
#  901: 'word_count_for_throbbing',
#  902: 'word_count_for_maneuvers',
#  903: 'word_count_for_concepts',
#  904: 'word_count_for_fit',
#  905: 'word_count_for_flesh',
#  906: 'word_count_for_cartoons',
#  907: 'word_count_for_self-righteous',
#  908: 'word_count_for_cult',
#  909: 'word_count_for_highly-praised',
#  910: 'word_count_for_innovations',
#  911: 'word_count_for_Warrior',
#  912: 'word_count_for_grandness',
#  913: 'word_count_for_liberal',
#  914: 'word_count_for_upends',
#  915: 'word_count_for_highs',
#  916: 'word_count_for_unusually',
#  917: 'word_count_for_Have',
#  918: 'word_count_for_Eudora',
#  919: 'word_count_for_conditions',
#  920: 'word_count_for_Driven',
#  921: 'word_count_for_scan',
#  922: 'word_count_for_Lion',
#  923: 'word_count_for_opera-ish',
#  924: 'word_count_for_irrational',
#  925: 'word_count_for_Ian',
#  926: 'word_count_for_Derailed',
#  927: 'word_count_for_illuminating',
#  928: 'word_count_for_Diaries',
#  929: 'word_count_for_contradictory',
#  930: 'word_count_for_unleashed',
#  931: 'word_count_for_reaching',
#  932: 'word_count_for_incredibly',
#  933: 'word_count_for_fixated',
#  934: 'word_count_for_Newfoundland',
#  935: 'word_count_for_Precocious',
#  936: 'word_count_for_2,500',
#  937: 'word_count_for_spaces',
#  938: 'word_count_for_barn-side',
#  939: 'word_count_for_perpetually',
#  940: 'word_count_for_Muzak',
#  941: 'word_count_for_horror',
#  942: 'word_count_for_levels',
#  943: 'word_count_for_disconnects',
#  944: 'word_count_for_Unless',
#  945: 'word_count_for_disastrous',
#  946: 'word_count_for_crave',
#  947: 'word_count_for_Ally',
#  948: 'word_count_for_condensed',
#  949: 'word_count_for_recognizably',
#  950: 'word_count_for_freezers',
#  951: 'word_count_for_towards',
#  952: 'word_count_for_via',
#  953: 'word_count_for_enamored',
#  954: 'word_count_for_eludes',
#  955: 'word_count_for_potential',
#  956: 'word_count_for_prima',
#  957: 'word_count_for_instrument',
#  958: 'word_count_for_lingual',
#  959: 'word_count_for_longest',
#  960: 'word_count_for_somber',
#  961: 'word_count_for_wig',
#  962: 'word_count_for_quasi-documentary',
#  963: 'word_count_for_poof',
#  964: 'word_count_for_accept',
#  965: 'word_count_for_Rabbit-Proof',
#  966: 'word_count_for_joy',
#  967: 'word_count_for_currently',
#  968: 'word_count_for_forte',
#  969: 'word_count_for_alternate',
#  970: 'word_count_for_2455',
#  971: 'word_count_for_cloyingly',
#  972: 'word_count_for_English',
#  973: 'word_count_for_imitator',
#  974: 'word_count_for_sunset',
#  975: 'word_count_for_revolutionary',
#  976: 'word_count_for_Fortunately',
#  977: 'word_count_for_Serious',
#  978: 'word_count_for_LDS',
#  979: 'word_count_for_me',
#  980: 'word_count_for_turgid',
#  981: 'word_count_for_twice',
#  982: 'word_count_for_kiss',
#  983: 'word_count_for_Cineasts',
#  984: 'word_count_for_T',
#  985: 'word_count_for_wrong',
#  986: 'word_count_for_tooth',
#  987: 'word_count_for_thrives',
#  988: 'word_count_for_barrel',
#  989: 'word_count_for_Matrix',
#  990: 'word_count_for_pandering',
#  991: 'word_count_for_obscenity',
#  992: 'word_count_for_tops',
#  993: 'word_count_for_Satisfyingly',
#  994: 'word_count_for_seas',
#  995: 'word_count_for_Malik',
#  996: 'word_count_for_counter',
#  997: 'word_count_for_current',
#  998: 'word_count_for_Fails',
#  999: 'word_count_for_backhanded',
#  ...}

# %% [markdown]
# ## A linear classifier: Logistic Regression

# %% [markdown]
# We can now build the classifier for this dataset. We’ll be using the LogisticRegression class from Scikit-learn.
#
# Install Scikit Learn from terminal:

# %% [raw]
# conda install scikit-learn

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()

# %% [markdown]
# In order to train our model to our dataset, we use Scikit-learn’s fit method to do so. This is where our ML classifier actually learns the underlying functions that produce our results.

# %%
X_train = [x['vector'] for x in training_set]
y_train = [x['label'] for x in training_set]
log_model = log_model.fit(X=X_train, y=y_train)

# %% [markdown]
# And finally, we apply `log_model.predict()` to test the learned algorithm on the SST dev set:

# %%
X_dev = [x['vector'] for x in dev_set]
y_dev = [x['label'] for x in dev_set]

y_dev_pred = log_model.predict(X_dev)

# %% [markdown]
# ## Accuracy

# %% [markdown]
# We can now look at how accurate our function was:

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_dev_pred, y_dev))

# %% [markdown]
# ## Exercise
#
# * Tweak the features in `feature_function()` to improve accuracy. For example, add a new feature to your model that captures the effect of negation (commented out in `feature_function()`, you can play around with this to add more conditions to capture negation from text). You can also try adding more features, for e.g., that detect words indicating positive or negative emotions.
#
#     * Keep testing how your accuracy evolves as you tweak your model.
#     * Let's now compare our results in a show of hands. Who did better than 80%?
#
# <br>
#
# * You might have done well after tweaking your function over your development set. But you run into the risk that your model overfit the data you trained it on, i.e. it is too specialized and can only do well on that particular data. You can check whether this is the case on a new dataset, taken from IMDb:

# %%
x_test = [x['vector'] for x in imdb_test]
y_test = [x['label'] for x in imdb_test]

y_test_pred = log_model.predict(x_test)

print(accuracy_score(y_test_pred, y_test))

# %% [markdown]
# Did your model do as well?
