# %% [markdown]
# # Sentiment analysis (Exercise 4)

# %%
__author__ = "Xin Guan"
__version__ = "DSGA 1012, NYU, Spring 2018 term"

# %% [markdown]
# ## Setup

# %% [markdown]
# load the Stanford Sentiment Treebank. download it from here: [the train/dev/test Stanford Sentiment Treebank distribution](http://nlp.stanford.edu/sentiment/trainDevTestTrees_PTB.zip)

# %%
import re
import random
import os
import numpy as np
import collections

# %%
sst_home = 'trees'

def load_sst_data(path):
    # do 2-way positive/negative classification instead of 5-way
    EASY_LABEL_MAP = {0:0, 1:0, 2:None, 3:1, 4:1}
    
    data = []
    with open(path) as f:
        for i, line in enumerate(f): 
            example = {}
            example['label'] = EASY_LABEL_MAP[int(line[1])]
            if example['label'] is None:
                continue
            
            text = re.sub(r'\s*(\(\d)|(\))\s*', '', line)
            example['text'] = text[1:]
            data.append(example)

    return data
     
training_set = load_sst_data(sst_home + '/train.txt')
dev_set = load_sst_data(sst_home + '/dev.txt')
#test_set = load_sst_data(sst_home + '/test.txt')

# %% [markdown]
# using IMDb movie reviews as a test set later on. Download the data from "http://ai.stanford.edu/~amaas/data/sentiment/"
#
# reformats the data in the same form as  SST data.

# %%
imdb_home = 'aclImdb/test/'

def load_imdb_data(path):
    
    pos_data, neg_data = [], []
    all_files = []
    _limit = 250
    
    for dirpath, dirnames, files in os.walk(path):
        for name in files:
            all_files.append(os.path.join(dirpath, name))
            
            
    for file_path in all_files:
        if '/neg' in file_path and len(neg_data) <= _limit:
            example = {}
            with open(file_path, 'r') as myfile:
                example['text'] = myfile.read().replace('\n', '')
            example['label'] = 0
            neg_data.append(example)
            
        if '/pos' in file_path and len(pos_data) <= _limit:
            example = {}
            with open(file_path, 'r') as myfile:
                example['text'] = myfile.read().replace('\n', '')
            example['label'] = 1
            pos_data.append(example)
    data = neg_data + pos_data

    return data

            
imdb_test = load_imdb_data(imdb_home)

# %%
imdb_test[0]
# Out:
# {'label': 0,
#  'text': "Alan Rickman & Emma Thompson give good performances with southern/New Orleans accents in this detective flick. It's worth seeing for their scenes- and Rickman's scene with Hal Holbrook. These three actors mannage to entertain us no matter what the movie, it seems. The plot for the movie shows potential, but one gets the impression in watching the film that it was not pulled off as well as it could have been. The fact that it is cluttered by a rather uninteresting subplot and mostly uninteresting kidnappers really muddles things. The movie is worth a view- if for nothing more than entertaining performances by Rickman, Thompson, and Holbrook."}

# %% [markdown]
# Next, we build a function `feature_function()` that annotates datasets with feature vectors.

# %%
def feature_function(datasets):
    '''Annotates datasets with feature vectors.'''
                         
    # Extract vocabulary
    def tokenize(string):
        return string.split()
    
    word_counter = collections.Counter()
    for example in datasets[0]:
        word_counter.update(tokenize(example['text']))
    
    vocabulary = set([word for word in word_counter])

    feature_names = set()
    for i, dataset in enumerate(datasets):
        for example in dataset:
            example['features'] = collections.defaultdict(float)
        
            
            #Extract features (by name) for one example:
            word_counter = collections.Counter(tokenize(example['text']))
            for x in word_counter.items():
                if x[0] in vocabulary:
                    example["features"]["word_count_for_" + x[0]] = min(x[1], 1)
                    
#            '''
#                Adding Negation feature
#            '''        
#             if "n't" in example['text'] or "not" in example['text']:
#                 example["features"]["negation"] = 1
#             else:
#                 example["features"]["negation"] = 0
            
            feature_names.update(example['features'].keys())
                            
    # assign indices to them.
    feature_indices = dict(zip(feature_names, range(len(feature_names))))
    indices_to_features = {v: k for k, v in feature_indices.items()}
    dim = len(feature_indices)
                
    #  create actual vectors from those indices.
    for dataset in datasets:
        for example in dataset:
            example['vector'] = np.zeros((dim))
            for feature in example['features']:
                example['vector'][feature_indices[feature]] = example['features'][feature]
    return indices_to_features
    
indices_to_features = feature_function([training_set, dev_set, imdb_test])

# %%
indices_to_features
# Out:
# {0: 'word_count_for_fall',
#  1: 'word_count_for_proceeds',
#  2: 'word_count_for_fussing',
#  3: 'word_count_for_sneering',
#  4: 'word_count_for_knickknacks',
#  5: 'word_count_for_overstays',
#  6: 'word_count_for_ultra-provincial',
#  7: 'word_count_for_Literary',
#  8: 'word_count_for_unsatisfying',
#  9: 'word_count_for_Judaism',
#  10: 'word_count_for_downfall',
#  11: 'word_count_for_completely',
#  12: 'word_count_for_learning',
#  13: 'word_count_for_cracker',
#  14: 'word_count_for_annoying',
#  15: 'word_count_for_flair',
#  16: 'word_count_for_add',
#  17: 'word_count_for_Trains',
#  18: 'word_count_for_visible',
#  19: 'word_count_for_able',
#  20: 'word_count_for_shots',
#  21: 'word_count_for_downs',
#  22: 'word_count_for_warmest',
#  23: 'word_count_for_abuse',
#  24: 'word_count_for_Jewish',
#  25: 'word_count_for_cheapen',
#  26: 'word_count_for_rediscover',
#  27: 'word_count_for_disapproval',
#  28: 'word_count_for_gamut',
#  29: 'word_count_for_shriveled',
#  30: 'word_count_for_punishable',
#  31: 'word_count_for_Your',
#  32: 'word_count_for_chiaroscuro',
#  33: 'word_count_for_swiftly',
#  34: 'word_count_for_irrational',
#  35: 'word_count_for_dog-paddle',
#  36: 'word_count_for_Seigner',
#  37: 'word_count_for_uninspired',
#  38: 'word_count_for_Safe',
#  39: 'word_count_for_telling',
#  40: 'word_count_for_strong',
#  41: 'word_count_for_relevance',
#  42: 'word_count_for_Morrison',
#  43: 'word_count_for_Holmes',
#  44: 'word_count_for_reviewers',
#  45: 'word_count_for_freely',
#  46: 'word_count_for_Juwanna',
#  47: 'word_count_for_direct-to-video\\/DVD',
#  48: 'word_count_for_Dogtown',
#  49: 'word_count_for_Avon',
#  50: 'word_count_for_departure',
#  51: 'word_count_for_action',
#  52: 'word_count_for_Hennings',
#  53: 'word_count_for_dogged',
#  54: 'word_count_for_forgive',
#  55: 'word_count_for_principles',
#  56: 'word_count_for_Visually',
#  57: 'word_count_for_Fundamentals',
#  58: 'word_count_for_community-college',
#  59: 'word_count_for_pander',
#  60: 'word_count_for_Pipe',
#  61: 'word_count_for_vain',
#  62: 'word_count_for_Quitting',
#  63: 'word_count_for_feminist',
#  64: 'word_count_for_Beginners',
#  65: 'word_count_for_laws',
#  66: 'word_count_for_frames',
#  67: 'word_count_for_abject',
#  68: 'word_count_for_free-wheeling',
#  69: 'word_count_for_Age',
#  70: 'word_count_for_curse',
#  71: 'word_count_for_absurd',
#  72: 'word_count_for_Belt',
#  73: 'word_count_for_negate',
#  74: 'word_count_for_physical',
#  75: 'word_count_for_nothing',
#  76: 'word_count_for_lab',
#  77: 'word_count_for_simulate',
#  78: 'word_count_for_refugees',
#  79: 'word_count_for_beautifully',
#  80: 'word_count_for_thematically',
#  81: 'word_count_for_jokester',
#  82: 'word_count_for_Ocean',
#  83: 'word_count_for_afraid',
#  84: 'word_count_for_myself',
#  85: 'word_count_for_limbo',
#  86: 'word_count_for_unappealing',
#  87: 'word_count_for_late-summer',
#  88: 'word_count_for_intern',
#  89: 'word_count_for_Liu',
#  90: 'word_count_for_Especially',
#  91: 'word_count_for_Runyon',
#  92: 'word_count_for_publicists',
#  93: 'word_count_for_unsophisticated',
#  94: 'word_count_for_daredevils',
#  95: 'word_count_for_sit',
#  96: 'word_count_for_note',
#  97: 'word_count_for_Limps',
#  98: 'word_count_for_50-million',
#  99: 'word_count_for_extensive',
#  100: 'word_count_for_brainy',
#  101: 'word_count_for_precise',
#  102: 'word_count_for_ingratiating',
#  103: 'word_count_for_seem',
#  104: 'word_count_for_naughty',
#  105: 'word_count_for_assuming',
#  106: 'word_count_for_outward',
#  107: 'word_count_for_horses',
#  108: 'word_count_for_several',
#  109: 'word_count_for_mostly',
#  110: 'word_count_for_steadily',
#  111: 'word_count_for_Hossein',
#  112: 'word_count_for_reminders',
#  113: 'word_count_for_strands',
#  114: 'word_count_for_stereotypes',
#  115: 'word_count_for_signals',
#  116: 'word_count_for_uninventive',
#  117: 'word_count_for_mercilessly',
#  118: 'word_count_for_not',
#  119: 'word_count_for_loud',
#  120: 'word_count_for_ironies',
#  121: 'word_count_for_Screenwriting',
#  122: 'word_count_for_Doyle',
#  123: 'word_count_for_Audiard',
#  124: 'word_count_for_mix',
#  125: 'word_count_for_Tackles',
#  126: 'word_count_for_Brent',
#  127: 'word_count_for_awarded',
#  128: 'word_count_for_anchoring',
#  129: 'word_count_for_Mel',
#  130: 'word_count_for_openness',
#  131: 'word_count_for_sure-fire',
#  132: 'word_count_for_Summer',
#  133: 'word_count_for_Pauly',
#  134: 'word_count_for_sublimely',
#  135: 'word_count_for_La',
#  136: 'word_count_for_insultingly',
#  137: 'word_count_for_tendency',
#  138: 'word_count_for_Good-naturedly',
#  139: 'word_count_for_versus',
#  140: 'word_count_for_potential',
#  141: 'word_count_for_right',
#  142: 'word_count_for_narrated',
#  143: 'word_count_for_phonograph',
#  144: 'word_count_for_smallest',
#  145: 'word_count_for_Disgusting',
#  146: 'word_count_for_conceal',
#  147: 'word_count_for_rated',
#  148: 'word_count_for_unsuspecting',
#  149: 'word_count_for_grateful',
#  150: 'word_count_for_wrong',
#  151: 'word_count_for_clothes',
#  152: 'word_count_for_quiet',
#  153: 'word_count_for_embodies',
#  154: 'word_count_for_fascinates',
#  155: 'word_count_for_editing',
#  156: 'word_count_for_midnight',
#  157: 'word_count_for_not-nearly',
#  158: 'word_count_for_deliriously',
#  159: 'word_count_for_careful',
#  160: 'word_count_for_assault',
#  161: 'word_count_for_UK',
#  162: 'word_count_for_watches',
#  163: 'word_count_for_digital-effects-heavy',
#  164: 'word_count_for_cameras',
#  165: 'word_count_for_sneeze',
#  166: 'word_count_for_cascade',
#  167: 'word_count_for_grease',
#  168: 'word_count_for_Opening',
#  169: 'word_count_for_spookily',
#  170: 'word_count_for_sleaziness',
#  171: 'word_count_for_slap',
#  172: 'word_count_for_halfway',
#  173: 'word_count_for_plunge',
#  174: 'word_count_for_tenderly',
#  175: 'word_count_for_Claude',
#  176: 'word_count_for_sentiments',
#  177: 'word_count_for_cheesiest',
#  178: 'word_count_for_master',
#  179: 'word_count_for_Informative',
#  180: 'word_count_for_sleek',
#  181: 'word_count_for_Seriously',
#  182: 'word_count_for_Kilmer',
#  183: 'word_count_for_Sorvino',
#  184: 'word_count_for_She',
#  185: 'word_count_for_Cattaneo',
#  186: 'word_count_for_beasts',
#  187: 'word_count_for_important',
#  188: 'word_count_for_love-struck',
#  189: 'word_count_for_scrap',
#  190: 'word_count_for_cross-cultural',
#  191: 'word_count_for_length',
#  192: 'word_count_for_maternal',
#  193: 'word_count_for_Bride',
#  194: 'word_count_for_Gianni',
#  195: 'word_count_for_superlative',
#  196: 'word_count_for_Donald',
#  197: 'word_count_for_tweener',
#  198: 'word_count_for_afternoon',
#  199: 'word_count_for_reaches',
#  200: 'word_count_for_regarding',
#  201: 'word_count_for_pleas',
#  202: 'word_count_for_Cook',
#  203: 'word_count_for_water-camera',
#  204: 'word_count_for_Witherspoon',
#  205: 'word_count_for_secret',
#  206: 'word_count_for_kids-in-peril',
#  207: 'word_count_for_interpreting',
#  208: 'word_count_for_depth',
#  209: 'word_count_for_disobedience',
#  210: 'word_count_for_Bela',
#  211: 'word_count_for_preview',
#  212: 'word_count_for_domestic',
#  213: 'word_count_for_Sewer',
#  214: 'word_count_for_glitz',
#  215: 'word_count_for_analgesic',
#  216: 'word_count_for_pace',
#  217: 'word_count_for_ugliness',
#  218: 'word_count_for_studios',
#  219: 'word_count_for_soundtrack',
#  220: 'word_count_for_special',
#  221: 'word_count_for_bard',
#  222: 'word_count_for_provide',
#  223: 'word_count_for_Ruggero',
#  224: 'word_count_for_:',
#  225: 'word_count_for_dubious',
#  226: 'word_count_for_Kuras',
#  227: 'word_count_for_sip',
#  228: 'word_count_for_unparalleled',
#  229: 'word_count_for_arbitrarily',
#  230: 'word_count_for_slope',
#  231: 'word_count_for_notice',
#  232: 'word_count_for_Bogdanich',
#  233: 'word_count_for_available',
#  234: 'word_count_for_stores',
#  235: 'word_count_for_rude',
#  236: 'word_count_for_heartstrings',
#  237: 'word_count_for_Unfunny',
#  238: 'word_count_for_many',
#  239: 'word_count_for_well-contructed',
#  240: 'word_count_for_Majidi',
#  241: 'word_count_for_properly',
#  242: 'word_count_for_salute',
#  243: 'word_count_for_veers',
#  244: 'word_count_for_Mexican',
#  245: 'word_count_for_sickening',
#  246: 'word_count_for_Rothman',
#  247: 'word_count_for_ache',
#  248: 'word_count_for_patronizing',
#  249: 'word_count_for_rushed',
#  250: 'word_count_for_Fast',
#  251: 'word_count_for_schmucks',
#  252: 'word_count_for_laundry',
#  253: 'word_count_for_inferior',
#  254: 'word_count_for_shabby',
#  255: 'word_count_for_carnage',
#  256: 'word_count_for_limitations',
#  257: 'word_count_for_off-center',
#  258: 'word_count_for_Tyco',
#  259: 'word_count_for_Done',
#  260: 'word_count_for_swimfan',
#  261: 'word_count_for_perpetual',
#  262: 'word_count_for_agnostic',
#  263: 'word_count_for_cleverest',
#  264: 'word_count_for_indeed',
#  265: 'word_count_for_Triple',
#  266: 'word_count_for_guide',
#  267: 'word_count_for_mawkish',
#  268: 'word_count_for_engaged',
#  269: 'word_count_for_Hanussen',
#  270: 'word_count_for_cinematographer',
#  271: 'word_count_for_desperately',
#  272: 'word_count_for_irresistibly',
#  273: 'word_count_for_Department',
#  274: 'word_count_for_Weinstein',
#  275: 'word_count_for_crucial',
#  276: 'word_count_for_officer',
#  277: 'word_count_for_casual',
#  278: 'word_count_for_breezy',
#  279: 'word_count_for_Spare',
#  280: 'word_count_for_untalented',
#  281: 'word_count_for_my',
#  282: 'word_count_for_coos',
#  283: 'word_count_for_Escapes',
#  284: 'word_count_for_deafening',
#  285: 'word_count_for_anthropomorphic',
#  286: 'word_count_for_shockers',
#  287: 'word_count_for_flakeball',
#  288: 'word_count_for_trickster',
#  289: 'word_count_for_cussing',
#  290: 'word_count_for_framing',
#  291: 'word_count_for_cerebral',
#  292: 'word_count_for_alienation',
#  293: 'word_count_for_Swank',
#  294: 'word_count_for_subplot',
#  295: 'word_count_for_teen',
#  296: 'word_count_for_Late',
#  297: 'word_count_for_creating',
#  298: 'word_count_for_insistent',
#  299: 'word_count_for_Swimming',
#  300: 'word_count_for_measure',
#  301: 'word_count_for_Dodger',
#  302: 'word_count_for_breasts',
#  303: 'word_count_for_Block',
#  304: 'word_count_for_subtitles',
#  305: 'word_count_for_switches',
#  306: 'word_count_for_Amy',
#  307: 'word_count_for_Harry',
#  308: 'word_count_for_Letter',
#  309: 'word_count_for_pasts',
#  310: 'word_count_for_OK',
#  311: 'word_count_for_National',
#  312: 'word_count_for_Dumas',
#  313: 'word_count_for_brazenly',
#  314: 'word_count_for_joyful',
#  315: 'word_count_for_sons',
#  316: 'word_count_for_non-porn',
#  317: 'word_count_for_Neverland',
#  318: 'word_count_for_obsessive',
#  319: 'word_count_for_Gaghan',
#  320: 'word_count_for_involved',
#  321: 'word_count_for_serial',
#  322: 'word_count_for_lady',
#  323: 'word_count_for_shovel',
#  324: 'word_count_for_sisters',
#  325: 'word_count_for_failure',
#  326: 'word_count_for_melancholic',
#  327: 'word_count_for_Dungeons',
#  328: 'word_count_for_activism',
#  329: 'word_count_for_Deep',
#  330: 'word_count_for_Audience',
#  331: 'word_count_for_Conduct',
#  332: 'word_count_for_Streets',
#  333: 'word_count_for_endangered',
#  334: 'word_count_for_Think',
#  335: 'word_count_for_longtime',
#  336: 'word_count_for_bickering',
#  337: 'word_count_for_pig',
#  338: 'word_count_for_there',
#  339: 'word_count_for_leash',
#  340: 'word_count_for_luster',
#  341: 'word_count_for_energy',
#  342: 'word_count_for_separate',
#  343: "word_count_for_'70s",
#  344: 'word_count_for_stabs',
#  345: 'word_count_for_today',
#  346: 'word_count_for_capably',
#  347: 'word_count_for_Cat',
#  348: 'word_count_for_lugubrious',
#  349: 'word_count_for_self-mocking',
#  350: 'word_count_for_impacts',
#  351: 'word_count_for_sports',
#  352: 'word_count_for_observant',
#  353: 'word_count_for_beast',
#  354: 'word_count_for_pervasive',
#  355: 'word_count_for_wafer-thin',
#  356: 'word_count_for_Nation',
#  357: 'word_count_for_interests',
#  358: 'word_count_for_really',
#  359: 'word_count_for_coldest',
#  360: 'word_count_for_Very',
#  361: 'word_count_for_resurrection',
#  362: 'word_count_for_dynamics',
#  363: 'word_count_for_Mafia',
#  364: 'word_count_for_flowering',
#  365: 'word_count_for_Boasting',
#  366: 'word_count_for_unrelenting',
#  367: 'word_count_for_in-your-face',
#  368: 'word_count_for_traditionally',
#  369: 'word_count_for_dragons',
#  370: 'word_count_for_PG-13',
#  371: 'word_count_for_river',
#  372: 'word_count_for_pseudo-serious',
#  373: 'word_count_for_limpid',
#  374: 'word_count_for_X-Files',
#  375: 'word_count_for_Greenlight',
#  376: 'word_count_for_trouble',
#  377: 'word_count_for_identity-seeking',
#  378: 'word_count_for_okay',
#  379: 'word_count_for_shows',
#  380: 'word_count_for_treasure',
#  381: 'word_count_for_healthy',
#  382: 'word_count_for_passing',
#  383: 'word_count_for_unimaginatively',
#  384: 'word_count_for_likeable',
#  385: 'word_count_for_Funny',
#  386: 'word_count_for_breakdown',
#  387: 'word_count_for_swept',
#  388: 'word_count_for_tepid',
#  389: 'word_count_for_PB',
#  390: 'word_count_for_Secretary',
#  391: 'word_count_for_expanse',
#  392: 'word_count_for_rip-roaring',
#  393: 'word_count_for_concentrating',
#  394: 'word_count_for_pocket',
#  395: 'word_count_for_merrily',
#  396: 'word_count_for_dead',
#  397: 'word_count_for_Makhmalbaf',
#  398: 'word_count_for_Digest',
#  399: 'word_count_for_mischievous',
#  400: 'word_count_for_Goodfellas',
#  401: 'word_count_for_interviewees',
#  402: 'word_count_for_missive',
#  403: 'word_count_for_customarily',
#  404: 'word_count_for_Kraft',
#  405: 'word_count_for_islanders',
#  406: 'word_count_for_mid',
#  407: 'word_count_for_literally',
#  408: 'word_count_for_Year',
#  409: 'word_count_for_uncomfortable',
#  410: 'word_count_for_repellent',
#  411: 'word_count_for_docs',
#  412: 'word_count_for_Sellers',
#  413: 'word_count_for_3\\/4th',
#  414: 'word_count_for_odyssey',
#  415: 'word_count_for_salaries',
#  416: 'word_count_for_support',
#  417: 'word_count_for_succeeds',
#  418: 'word_count_for_shedding',
#  419: 'word_count_for_tougher',
#  420: 'word_count_for_Rarely',
#  421: 'word_count_for_revision',
#  422: 'word_count_for_Westbrook',
#  423: 'word_count_for_sociology',
#  424: 'word_count_for_pressed',
#  425: 'word_count_for_unrealized',
#  426: 'word_count_for_magic',
#  427: 'word_count_for_one-dimensional',
#  428: 'word_count_for_lo',
#  429: 'word_count_for_sketched',
#  430: 'word_count_for_natural',
#  431: 'word_count_for_inexperienced',
#  432: 'word_count_for_shell',
#  433: 'word_count_for_without',
#  434: 'word_count_for_Medem',
#  435: 'word_count_for_patch',
#  436: 'word_count_for_outdated',
#  437: 'word_count_for_friendships',
#  438: 'word_count_for_exhibitionism',
#  439: 'word_count_for_intact',
#  440: 'word_count_for_strike',
#  441: 'word_count_for_statements',
#  442: 'word_count_for_find',
#  443: 'word_count_for_Proof',
#  444: 'word_count_for_hoot',
#  445: 'word_count_for_Delight',
#  446: 'word_count_for_disturbing',
#  447: 'word_count_for_Samuel',
#  448: 'word_count_for_recommend',
#  449: 'word_count_for_Sea',
#  450: 'word_count_for_Leaves',
#  451: 'word_count_for_climbing',
#  452: 'word_count_for_fright',
#  453: 'word_count_for_Franc',
#  454: 'word_count_for_slump',
#  455: 'word_count_for_less',
#  456: 'word_count_for_propensity',
#  457: 'word_count_for_pretence',
#  458: 'word_count_for_hipness',
#  459: 'word_count_for_restrained',
#  460: 'word_count_for_ranks',
#  461: 'word_count_for_9',
#  462: 'word_count_for_amaze',
#  463: 'word_count_for_mean',
#  464: 'word_count_for_writers',
#  465: 'word_count_for_twitchy',
#  466: 'word_count_for_Zealand',
#  467: 'word_count_for_ballroom',
#  468: 'word_count_for_nutty',
#  469: 'word_count_for_Collateral',
#  470: 'word_count_for_actual',
#  471: 'word_count_for_Kaufman',
#  472: 'word_count_for_crowd-pleasing',
#  473: 'word_count_for_escapade',
#  474: 'word_count_for_hampered',
#  475: 'word_count_for_fu',
#  476: 'word_count_for_lend',
#  477: 'word_count_for_war-movie',
#  478: 'word_count_for_veered',
#  479: 'word_count_for_soap-opera',
#  480: 'word_count_for_Kenneth',
#  481: 'word_count_for_overtly',
#  482: 'word_count_for_fluffy',
#  483: 'word_count_for_endurance',
#  484: 'word_count_for_Ill-considered',
#  485: 'word_count_for_change',
#  486: 'word_count_for_spaceship',
#  487: 'word_count_for_wasted',
#  488: 'word_count_for_despite',
#  489: 'word_count_for_unlikable',
#  490: 'word_count_for_extent',
#  491: 'word_count_for_Comic',
#  492: 'word_count_for_Brussels',
#  493: 'word_count_for_thrilling',
#  494: 'word_count_for_dedication',
#  495: 'word_count_for_two-thirds',
#  496: 'word_count_for_cloying',
#  497: 'word_count_for_conceivable',
#  498: 'word_count_for_prefabricated',
#  499: 'word_count_for_Splash',
#  500: 'word_count_for_neighbor',
#  501: 'word_count_for_let-down',
#  502: 'word_count_for_before',
#  503: 'word_count_for_testosterone-charged',
#  504: 'word_count_for_cumulative',
#  505: 'word_count_for_adherents',
#  506: 'word_count_for_tediously',
#  507: 'word_count_for_off-kilter',
#  508: 'word_count_for_sole',
#  509: 'word_count_for_mental',
#  510: 'word_count_for_sits',
#  511: 'word_count_for_pay',
#  512: 'word_count_for_disarmingly',
#  513: 'word_count_for_edited',
#  514: 'word_count_for_clips',
#  515: 'word_count_for_vaguely',
#  516: 'word_count_for_heck',
#  517: 'word_count_for_-',
#  518: 'word_count_for_survivors',
#  519: 'word_count_for_iteration',
#  520: 'word_count_for_Banal',
#  521: 'word_count_for_Written',
#  522: 'word_count_for_avarice',
#  523: 'word_count_for_lectured',
#  524: 'word_count_for_potent',
#  525: 'word_count_for_presiding',
#  526: 'word_count_for_Vicente',
#  527: 'word_count_for_Battlefield',
#  528: 'word_count_for_settled',
#  529: 'word_count_for_Little',
#  530: 'word_count_for_polemic',
#  531: 'word_count_for_hotels',
#  532: 'word_count_for_well-intentioned',
#  533: 'word_count_for_inquisitive',
#  534: 'word_count_for_crassly',
#  535: 'word_count_for_TUCK',
#  536: 'word_count_for_clinically',
#  537: 'word_count_for_Mehta',
#  538: 'word_count_for_artistes',
#  539: 'word_count_for_bluff',
#  540: 'word_count_for_Throwing',
#  541: 'word_count_for_formula',
#  542: 'word_count_for_displays',
#  543: 'word_count_for_view',
#  544: 'word_count_for_painful',
#  545: 'word_count_for_Clever',
#  546: 'word_count_for_Liana',
#  547: 'word_count_for_pie',
#  548: 'word_count_for_disrobed',
#  549: 'word_count_for_cobbled',
#  550: 'word_count_for_shines',
#  551: 'word_count_for_Move',
#  552: 'word_count_for_sharing',
#  553: 'word_count_for_reverence',
#  554: 'word_count_for_toolbags',
#  555: 'word_count_for_Demme',
#  556: 'word_count_for_anti-war',
#  557: 'word_count_for_disguise',
#  558: 'word_count_for_French',
#  559: 'word_count_for_tap',
#  560: 'word_count_for_simple-minded',
#  561: 'word_count_for_stereotypical',
#  562: 'word_count_for_worthy',
#  563: 'word_count_for_ill-equipped',
#  564: 'word_count_for_self-satisfaction',
#  565: 'word_count_for_dearly',
#  566: 'word_count_for_quirky',
#  567: 'word_count_for_silver',
#  568: 'word_count_for_university',
#  569: 'word_count_for_faces',
#  570: 'word_count_for_rises',
#  571: 'word_count_for_hideous',
#  572: 'word_count_for_amicable',
#  573: 'word_count_for_tumultuous',
#  574: 'word_count_for_Pan',
#  575: 'word_count_for_Elegantly',
#  576: 'word_count_for_Melds',
#  577: 'word_count_for_Ultimate',
#  578: 'word_count_for_Merchant',
#  579: 'word_count_for_formidable',
#  580: 'word_count_for_hunky',
#  581: 'word_count_for_scarcely',
#  582: 'word_count_for_1920',
#  583: 'word_count_for_Director',
#  584: 'word_count_for_all-enveloping',
#  585: 'word_count_for_choreography',
#  586: 'word_count_for_Secret',
#  587: 'word_count_for_Befuddled',
#  588: 'word_count_for_Finch',
#  589: 'word_count_for_surface',
#  590: 'word_count_for_Phifer',
#  591: 'word_count_for_pleased',
#  592: 'word_count_for_leftovers',
#  593: 'word_count_for_chance',
#  594: 'word_count_for_Texan',
#  595: 'word_count_for_you-are-there',
#  596: 'word_count_for_Khan',
#  597: 'word_count_for_bang-bang',
#  598: 'word_count_for_impersonal',
#  599: 'word_count_for_96',
#  600: 'word_count_for_Mitch',
#  601: 'word_count_for_windows',
#  602: 'word_count_for_Tang',
#  603: 'word_count_for_harmed',
#  604: 'word_count_for_disposible',
#  605: 'word_count_for_aching',
#  606: 'word_count_for_admirers',
#  607: 'word_count_for_Mobius',
#  608: 'word_count_for_uncovers',
#  609: 'word_count_for_Adrian',
#  610: 'word_count_for_Mika',
#  611: 'word_count_for_replaced',
#  612: 'word_count_for_Don',
#  613: 'word_count_for_Press',
#  614: 'word_count_for_humorless',
#  615: 'word_count_for_regard',
#  616: 'word_count_for_colored',
#  617: 'word_count_for_observation',
#  618: 'word_count_for_appreciates',
#  619: 'word_count_for_tremble',
#  620: 'word_count_for_well-mounted',
#  621: 'word_count_for_workers',
#  622: 'word_count_for_faulty',
#  623: 'word_count_for_derailed',
#  624: 'word_count_for_tides',
#  625: 'word_count_for_bother',
#  626: 'word_count_for_heed',
#  627: 'word_count_for_Jonathan',
#  628: 'word_count_for_told',
#  629: 'word_count_for_If',
#  630: 'word_count_for_Mr.',
#  631: 'word_count_for_Africa',
#  632: 'word_count_for_balancing',
#  633: 'word_count_for_fun-loving',
#  634: 'word_count_for_scary',
#  635: 'word_count_for_recorded',
#  636: 'word_count_for_misconstrued',
#  637: 'word_count_for_final',
#  638: 'word_count_for_ethical',
#  639: 'word_count_for_challenges',
#  640: 'word_count_for_Mask',
#  641: 'word_count_for_majestic',
#  642: 'word_count_for_Flat',
#  643: 'word_count_for_sulky',
#  644: 'word_count_for_agent',
#  645: 'word_count_for_Rubbo',
#  646: 'word_count_for_kicking',
#  647: 'word_count_for_give-me-an-Oscar',
#  648: 'word_count_for_here',
#  649: 'word_count_for_matters',
#  650: 'word_count_for_be-bop',
#  651: 'word_count_for_humorously',
#  652: 'word_count_for_boisterous',
#  653: 'word_count_for_head-turner',
#  654: 'word_count_for_squaddie',
#  655: 'word_count_for_failings',
#  656: 'word_count_for_Looks',
#  657: 'word_count_for_cares',
#  658: 'word_count_for_fishy',
#  659: 'word_count_for_falters',
#  660: 'word_count_for_dolorous',
#  661: 'word_count_for_shaky',
#  662: 'word_count_for_muting',
#  663: 'word_count_for_race',
#  664: 'word_count_for_deliciously',
#  665: 'word_count_for_following',
#  666: 'word_count_for_inevitable',
#  667: 'word_count_for_cocky',
#  668: 'word_count_for_Writer-director',
#  669: 'word_count_for_results',
#  670: 'word_count_for_princess',
#  671: 'word_count_for_tailor-made',
#  672: 'word_count_for_divertissement',
#  673: 'word_count_for_family-oriented',
#  674: 'word_count_for_Satisfyingly',
#  675: 'word_count_for_inert',
#  676: 'word_count_for_earthly',
#  677: 'word_count_for_wrought',
#  678: 'word_count_for_pivotal',
#  679: 'word_count_for_masterly',
#  680: 'word_count_for_Eve',
#  681: 'word_count_for_Batman',
#  682: 'word_count_for_melange',
#  683: 'word_count_for_sources',
#  684: 'word_count_for_decrepit',
#  685: 'word_count_for_Romanek',
#  686: 'word_count_for_tinsel',
#  687: 'word_count_for_serendipity',
#  688: 'word_count_for_Xerox',
#  689: 'word_count_for_dogs',
#  690: 'word_count_for_lump',
#  691: 'word_count_for_horrifying',
#  692: 'word_count_for_overwhelmingly',
#  693: 'word_count_for_acceptable',
#  694: 'word_count_for_garbled',
#  695: 'word_count_for_drying',
#  696: 'word_count_for_disparate',
#  697: 'word_count_for_vivre',
#  698: 'word_count_for_employ',
#  699: 'word_count_for_side',
#  700: 'word_count_for_pent',
#  701: 'word_count_for_lifestyle',
#  702: 'word_count_for_twin',
#  703: 'word_count_for_invite',
#  704: 'word_count_for_Videodrome',
#  705: 'word_count_for_marked',
#  706: 'word_count_for_prone',
#  707: 'word_count_for_sour',
#  708: 'word_count_for_thoughtfulness',
#  709: 'word_count_for_pretentious',
#  710: 'word_count_for_clarify',
#  711: 'word_count_for_dazzling',
#  712: 'word_count_for_liked',
#  713: 'word_count_for_Ms.',
#  714: 'word_count_for_grumble',
#  715: 'word_count_for_Elfriede',
#  716: 'word_count_for_encourage',
#  717: 'word_count_for_match',
#  718: 'word_count_for_tunnels',
#  719: 'word_count_for_Shapiro',
#  720: 'word_count_for_Jeong-Hyang',
#  721: 'word_count_for_third',
#  722: 'word_count_for_batting',
#  723: 'word_count_for_appreciated',
#  724: 'word_count_for_cultivated',
#  725: 'word_count_for_Dave',
#  726: 'word_count_for_Warrior',
#  727: 'word_count_for_opportunity',
#  728: 'word_count_for_porn',
#  729: 'word_count_for_covered',
#  730: 'word_count_for_Want',
#  731: 'word_count_for_Clown',
#  732: 'word_count_for_produced',
#  733: 'word_count_for_ease',
#  734: 'word_count_for_underconfident',
#  735: 'word_count_for_evening',
#  736: 'word_count_for_scary-funny',
#  737: 'word_count_for_establishes',
#  738: 'word_count_for_speaking',
#  739: 'word_count_for_Short',
#  740: 'word_count_for_Remove',
#  741: 'word_count_for_information',
#  742: 'word_count_for_Reigen',
#  743: 'word_count_for_deep-seated',
#  744: 'word_count_for_unfocused',
#  745: 'word_count_for_old-time',
#  746: 'word_count_for_louts',
#  747: 'word_count_for_appears',
#  748: 'word_count_for_populist',
#  749: 'word_count_for_impressionistic',
#  750: 'word_count_for_Fork',
#  751: 'word_count_for_129-minute',
#  752: 'word_count_for_Fingered',
#  753: 'word_count_for_Poetry',
#  754: 'word_count_for_Shimizu',
#  755: 'word_count_for_Waldo',
#  756: 'word_count_for_respites',
#  757: 'word_count_for_messiness',
#  758: 'word_count_for_season',
#  759: 'word_count_for_coasting',
#  760: 'word_count_for_irreversible',
#  761: 'word_count_for_Abomination',
#  762: 'word_count_for_Wait',
#  763: 'word_count_for_misfire',
#  764: 'word_count_for_abhorrent',
#  765: 'word_count_for_straight-to-video',
#  766: 'word_count_for_Bale',
#  767: 'word_count_for_thirty',
#  768: 'word_count_for_ours',
#  769: 'word_count_for_Purports',
#  770: 'word_count_for_Strikes',
#  771: 'word_count_for_Fears',
#  772: 'word_count_for_pitched',
#  773: 'word_count_for_preferably',
#  774: 'word_count_for_pomposity',
#  775: 'word_count_for_ebullient',
#  776: 'word_count_for_Caesar',
#  777: 'word_count_for_meshes',
#  778: 'word_count_for_gadgets',
#  779: 'word_count_for_hardy',
#  780: 'word_count_for_Jackie',
#  781: 'word_count_for_murky',
#  782: 'word_count_for_Whether',
#  783: 'word_count_for_torture',
#  784: 'word_count_for_barriers',
#  785: 'word_count_for_homage',
#  786: 'word_count_for_vividly',
#  787: 'word_count_for_saving',
#  788: 'word_count_for_aboriginal',
#  789: 'word_count_for_not-so-funny',
#  790: 'word_count_for_surely',
#  791: 'word_count_for_jealousy',
#  792: 'word_count_for_transforms',
#  793: 'word_count_for_Beavis',
#  794: 'word_count_for_Smarter',
#  795: 'word_count_for_grand',
#  796: 'word_count_for_McCracken',
#  797: 'word_count_for_Thornberry',
#  798: 'word_count_for_comprehension',
#  799: 'word_count_for_dialog',
#  800: 'word_count_for_Thurman',
#  801: 'word_count_for_choose',
#  802: 'word_count_for_violence',
#  803: 'word_count_for_Australia',
#  804: 'word_count_for_dozens',
#  805: 'word_count_for_present',
#  806: 'word_count_for_teaming',
#  807: 'word_count_for_Alien',
#  808: 'word_count_for_human-scale',
#  809: 'word_count_for_Brothers-style',
#  810: 'word_count_for_inconsistencies',
#  811: 'word_count_for_changing',
#  812: 'word_count_for_must',
#  813: 'word_count_for_small-scale',
#  814: 'word_count_for_overpowered',
#  815: 'word_count_for_respite',
#  816: 'word_count_for_unexpectedly',
#  817: 'word_count_for_smoothly',
#  818: 'word_count_for_thesps',
#  819: 'word_count_for_winners',
#  820: 'word_count_for_sympathizing',
#  821: 'word_count_for_harmoniously',
#  822: 'word_count_for_lines',
#  823: 'word_count_for_delicately',
#  824: 'word_count_for_communication',
#  825: 'word_count_for_assimilated',
#  826: 'word_count_for_expertly',
#  827: 'word_count_for_adaptation',
#  828: 'word_count_for_horrified',
#  829: 'word_count_for_richer',
#  830: 'word_count_for_dared',
#  831: 'word_count_for_million',
#  832: 'word_count_for_operative',
#  833: 'word_count_for_tinge',
#  834: 'word_count_for_moved',
#  835: 'word_count_for_spookiness',
#  836: 'word_count_for_charred',
#  837: 'word_count_for_affectingly',
#  838: 'word_count_for_capricious',
#  839: 'word_count_for_very',
#  840: 'word_count_for_so-called',
#  841: 'word_count_for_Fast-paced',
#  842: 'word_count_for_spectacle',
#  843: 'word_count_for_guise',
#  844: 'word_count_for_Molly',
#  845: 'word_count_for_volatile',
#  846: 'word_count_for_justify',
#  847: 'word_count_for_creed',
#  848: 'word_count_for_reprieve',
#  849: 'word_count_for_Lucia',
#  850: 'word_count_for_answered',
#  851: 'word_count_for_pies',
#  852: 'word_count_for_wondrously',
#  853: 'word_count_for_emergence',
#  854: 'word_count_for_Hélène',
#  855: 'word_count_for_Spike',
#  856: 'word_count_for_lunatic',
#  857: 'word_count_for_history',
#  858: 'word_count_for_self-important',
#  859: 'word_count_for_variant',
#  860: 'word_count_for_money-grubbing',
#  861: 'word_count_for_assurance',
#  862: 'word_count_for_discourse',
#  863: 'word_count_for_mighty',
#  864: 'word_count_for_capitalizes',
#  865: 'word_count_for_retro-refitting',
#  866: 'word_count_for_wry',
#  867: 'word_count_for_Shore',
#  868: 'word_count_for_misery',
#  869: 'word_count_for_Cheap',
#  870: 'word_count_for_suggesting',
#  871: 'word_count_for_age',
#  872: 'word_count_for_Zemeckis',
#  873: 'word_count_for_smarter',
#  874: 'word_count_for_Bank',
#  875: 'word_count_for_Cuaron',
#  876: 'word_count_for_Joseph',
#  877: 'word_count_for_awful',
#  878: 'word_count_for_facetious',
#  879: 'word_count_for_P',
#  880: 'word_count_for_pains',
#  881: 'word_count_for_Could',
#  882: 'word_count_for_ritual',
#  883: 'word_count_for_inter-family',
#  884: 'word_count_for_ripening',
#  885: 'word_count_for_Quinn',
#  886: 'word_count_for_vacuous',
#  887: 'word_count_for_assassination',
#  888: 'word_count_for_Returning',
#  889: 'word_count_for_sweetly',
#  890: 'word_count_for_Damage',
#  891: 'word_count_for_aware',
#  892: 'word_count_for_treachery',
#  893: 'word_count_for_coffee',
#  894: 'word_count_for_servants',
#  895: 'word_count_for_misunderstood',
#  896: 'word_count_for_mid-to-low',
#  897: 'word_count_for_wondrous',
#  898: 'word_count_for_high-octane',
#  899: 'word_count_for_weary',
#  900: 'word_count_for_inhuman',
#  901: 'word_count_for_squashed',
#  902: 'word_count_for_Perry',
#  903: 'word_count_for_lags',
#  904: 'word_count_for_bleak',
#  905: 'word_count_for_con',
#  906: 'word_count_for_producing',
#  907: 'word_count_for_women',
#  908: 'word_count_for_letter',
#  909: 'word_count_for_moron',
#  910: 'word_count_for_satirical',
#  911: 'word_count_for_models',
#  912: 'word_count_for_splatter',
#  913: 'word_count_for_Spectacularly',
#  914: 'word_count_for_passes',
#  915: 'word_count_for_Aspires',
#  916: 'word_count_for_eccentrics',
#  917: 'word_count_for_suffered',
#  918: 'word_count_for_immature',
#  919: 'word_count_for_correctness',
#  920: 'word_count_for_bouts',
#  921: 'word_count_for_grownups',
#  922: 'word_count_for_storyteller',
#  923: 'word_count_for_movie-going',
#  924: 'word_count_for_unmotivated',
#  925: 'word_count_for_horizons',
#  926: 'word_count_for_Dull',
#  927: 'word_count_for_Jacques',
#  928: 'word_count_for_homogenized',
#  929: 'word_count_for_doting',
#  930: 'word_count_for_juice',
#  931: 'word_count_for_asked',
#  932: 'word_count_for_Dwarfs',
#  933: 'word_count_for_subsequent',
#  934: 'word_count_for_G-rated',
#  935: 'word_count_for_silly-looking',
#  936: 'word_count_for_hearing',
#  937: 'word_count_for_bed',
#  938: 'word_count_for_Anemic',
#  939: 'word_count_for_filmmakers',
#  940: 'word_count_for_cup',
#  941: 'word_count_for_Woo',
#  942: 'word_count_for_Wave',
#  943: 'word_count_for_silly',
#  944: 'word_count_for_whining',
#  945: 'word_count_for_community',
#  946: 'word_count_for_simple',
#  947: 'word_count_for_underwater',
#  948: 'word_count_for_rates',
#  949: 'word_count_for_50-something',
#  950: 'word_count_for_accurate',
#  951: 'word_count_for_folds',
#  952: 'word_count_for_Ana',
#  953: 'word_count_for_suspects',
#  954: 'word_count_for_exclamation',
#  955: 'word_count_for_Choppy',
#  956: 'word_count_for_D.',
#  957: 'word_count_for_among',
#  958: 'word_count_for_Cam',
#  959: 'word_count_for_balances',
#  960: 'word_count_for_Horrendously',
#  961: 'word_count_for_difficult',
#  962: 'word_count_for_Hopelessly',
#  963: 'word_count_for_Americans',
#  964: 'word_count_for_Ambrose',
#  965: 'word_count_for_tattered',
#  966: 'word_count_for_hypocrisy',
#  967: 'word_count_for_Bloody',
#  968: 'word_count_for_jazzy',
#  969: 'word_count_for_invaders',
#  970: 'word_count_for_bona',
#  971: 'word_count_for_run',
#  972: 'word_count_for_Campbell',
#  973: 'word_count_for_Norwegian',
#  974: 'word_count_for_personas',
#  975: 'word_count_for_meaningful',
#  976: 'word_count_for_macabre',
#  977: 'word_count_for_mother',
#  978: 'word_count_for_Uplifting',
#  979: 'word_count_for_supposed',
#  980: 'word_count_for_miracle',
#  981: 'word_count_for_Movie',
#  982: 'word_count_for_Band',
#  983: 'word_count_for_surehanded',
#  984: 'word_count_for_Calvin',
#  985: 'word_count_for_moronic',
#  986: 'word_count_for_dig',
#  987: 'word_count_for_wiggling',
#  988: 'word_count_for_rests',
#  989: 'word_count_for_Believer',
#  990: 'word_count_for_panoramic',
#  991: 'word_count_for_chatter',
#  992: 'word_count_for_Driver-esque',
#  993: 'word_count_for_all-time',
#  994: 'word_count_for_Bow',
#  995: 'word_count_for_Morvern',
#  996: 'word_count_for_decline',
#  997: 'word_count_for_slow-motion',
#  998: 'word_count_for_compliment',
#  999: 'word_count_for_pulp',
#  ...}

# %% [markdown]
# ## A linear classifier: Logistic Regression

# %% [markdown]
# use the LogisticRegression class from Scikit-learn to build the classifier for this dataset

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()

# %%
X_train = [x['vector'] for x in training_set]
y_train = [x['label'] for x in training_set]
log_model = log_model.fit(X=X_train, y=y_train)

# %%
X_dev = [x['vector'] for x in dev_set]
y_dev = [x['label'] for x in dev_set]

y_dev_pred = log_model.predict(X_dev)

# %% [markdown]
# ## Accuracy

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_dev_pred, y_dev))
# Out:
# 0.7798165137614679

# %%
x_test = [x['vector'] for x in imdb_test]
y_test = [x['label'] for x in imdb_test]

y_test_pred = log_model.predict(x_test)

print(accuracy_score(y_test_pred, y_test))
# Out:
# 0.7729083665338645
